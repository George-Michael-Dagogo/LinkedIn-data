# %%
pip install requests bs4 fake_useragent pandas psycopg2_binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.32.4)
# Requirement already satisfied: bs4 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: fake_useragent in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: pandas in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: psycopg2_binary in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.9.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (2025.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (3.4.2)
# Requirement already satisfied: beautifulsoup4 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from bs4) (4.13.4)
# Requirement already satisfied: numpy>=1.22.4 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: pytz>=2020.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from beautifulsoup4->bs4) (4.14.0)
# Requirement already satisfied: soupsieve>1.2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from beautifulsoup4->bs4) (2.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import pandas as pd
import os
import psycopg2

title = 'data+engineer'

work_model = {'1': 'On-site', '2': 'Remote', '3': 'Hybrid'}
job_ids = set()
job_work_model = {}

for n_results in range(0,21,10):
    id_WM = random.choice(list(work_model.keys()))
    list_url = f'https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords={title}&location=United%20States&geoId=103644278&f_WT={id_WM}&sortBy=DD&start={n_results}'

    
    ua = UserAgent()
    userAgent = ua.random
    headers = {'User-Agent': userAgent}
    response = requests.get(list_url, headers = headers)

    list_data = response.text
    list_soup = BeautifulSoup(list_data, 'html.parser')
    job_cards = list_soup.find_all('div', class_='base-card')

    for card in job_cards:
        if 'data-entity-urn' in card.attrs:
            job_id = card['data-entity-urn'].split(':')[3]
            job_ids.add(job_id)
            job_work_model[job_id] = work_model[id_WM]

job_ids = list(job_ids)

# %%
job_list = []

for job_id in job_ids:
    ua = UserAgent()
    userAgent = ua.random
    headers = {'User-Agent': userAgent}
    job_url = f'https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}?_l=en_US'
    job_response = requests.get(job_url, headers = headers)
    # print(job_response.status_code)

    if job_response.status_code == 200:
        job_post = {}
        job_soup = BeautifulSoup(job_response.text, 'html.parser')

        job_post['job_id'] = job_id

        try:
            job_post['job_title'] = job_soup.find('h2', {'class': 'top-card-layout__title'}).text.strip()
        except:
            job_post['job_title'] = None

        try:
            job_post['company_name'] = job_soup.find('a', {'class': 'topcard__org-name-link'}).text.strip()
        except:
            job_post['company_name'] = None

        job_post['work_model'] = job_work_model.get(job_id, None)

        try:
            job_post['location'] = job_soup.find('span', {'class': 'topcard__flavor topcard__flavor--bullet'}).text.strip()
        except:
            job_post['location'] = None   

        try:
            job_post['time_posted'] = job_soup.find('span', {'class': 'posted-time-ago__text'}).text.strip()
        except:
            job_post['time_posted'] = None

        try:
            job_post['num_applicants'] = job_soup.find('span', {'class': 'num-applicants__caption'}).text.strip()
        except:
            job_post['num_applicants'] = None
        
        job_criteria = {}
        for item in job_soup.find_all('li', class_='description__job-criteria-item'):
            try:
                label = item.find('h3', class_='description__job-criteria-subheader').text.strip()
                value = item.find('span', class_='description__job-criteria-text').text.strip()
                job_criteria[label] = value
            except:
                continue

        job_post['xp_level'] = job_criteria.get(list(job_criteria.keys())[0], None)
        job_post['job_type'] = job_criteria.get(list(job_criteria.keys())[1], None)
        job_post['job_sectors'] = job_criteria.get(list(job_criteria.keys())[3], None)

        try:
            job_post['job_description'] = job_soup.find('div', {'class': 'show-more-less-html__markup'}).get_text(separator="\n", strip=True)
        except:
            job_post['job_description'] = None

        job_list.append(job_post)


jobs_df = pd.DataFrame(job_list)
jobs_df
# Out:
#         job_id                                          job_title  \
# 0   4252403261                               Senior Data Engineer
# 1   4232940657                                      Data Engineer
# 2   4124931707                                      Data Engineer
# 3   4160656913                                      Data Engineer
# 4   4227411210                               Junior Data Engineer
# 5   4257708833  Data Engineer/Senior Data Engineer/Lead Data E...
# 6   3970353535                                      Data Engineer
# 7   4246012425                                      Data Engineer
# 8   4179982116  Data Engineer (L5) - Content Production & Prom...
# 9   4212085122                               Senior Data Engineer
# 10  4216499552                                      Data Engineer
# 11  4251972021                               Junior Data Engineer
# 12  4235550250                                      Data Engineer
# 13  4209905359                         Data Engineer 5 - Playback
# 14  4230106830                   Data Engineer - Data Engineering
# 15  4208343571  Software Engineer (L4) - Member, Commerce & Ga...
# 16  4209157444                                      Data Engineer
# 17  4233100791                                      Data Engineer
# 18  4260001898                                  Sr. Data Engineer
# 19  4254134391                               Senior Data Engineer
# 20  4260004537                                  Sr. Data Engineer
# 21  4255376438                               Senior Data Engineer
# 22  4243686674                                      Data Engineer
# 23  4187566335                          Data & Analytics Engineer
# 24  3970356046                                      Data Engineer
# 25  3970352584                                      Data Engineer
# 26  4239626016                                  Data Engineer III
# 27  4218006269                                      Data Engineer
#
#                                  company_name work_model  \
# 0                                       Asana     Hybrid
# 1                                 Middle Seat     Remote
# 2                                        Zoox     Hybrid
# 3                                       Finix     Hybrid
# 4                           Rize Credit Union     Hybrid
# 5                            ClearNote Health     Remote
# 6                                       Figma     Remote
# 7                     Lazard Asset Management     Hybrid
# 8                                     Netflix     Remote
# 9                                     Samsara     Remote
# 10                                     Ibotta     Hybrid
# 11                        The Value Maximizer     Hybrid
# 12                                      Paces     Hybrid
# 13                                    Netflix     Remote
# 14                                      Plaid     Hybrid
# 15                                    Netflix     Remote
# 16                                        BDG     Hybrid
# 17                                Leader Bank     Remote
# 18  CGS Federal (Contact Government Services)     Remote
# 19                                    Andiamo     Remote
# 20  CGS Federal (Contact Government Services)     Remote
# 21                       Procore Technologies     Remote
# 22                               Courtyard.io     Remote
# 23                                   MojoTech     Remote
# 24                                      Figma     Remote
# 25                                      Figma     Remote
# 26                                   Fanatics     Remote
# 27                                   Protecht     Remote
#
#                      location   time_posted num_applicants          xp_level  \
# 0           San Francisco, CA    1 week ago           None         Associate
# 1              Washington, DC   1 month ago           None       Entry level
# 2             Foster City, CA    1 week ago           None    Not Applicable
# 3           San Francisco, CA    2 days ago           None       Entry level
# 4               Irwindale, CA   1 month ago           None  Mid-Senior level
# 5               San Diego, CA    5 days ago           None  Mid-Senior level
# 6           San Francisco, CA    1 week ago           None  Mid-Senior level
# 7     New York, United States   2 weeks ago           None       Entry level
# 8               United States    2 days ago           None    Not Applicable
# 9               United States    3 days ago           None  Mid-Senior level
# 10                 Denver, CO   2 weeks ago           None       Entry level
# 11  New Jersey, United States    1 week ago  30 applicants  Mid-Senior level
# 12               Brooklyn, NY   1 month ago           None       Entry level
# 13              United States    1 week ago           None    Not Applicable
# 14          San Francisco, CA    5 days ago           None  Mid-Senior level
# 15              United States    5 days ago           None    Not Applicable
# 16               New York, NY   1 month ago           None       Entry level
# 17              United States   8 hours ago           None       Entry level
# 18              United States     1 day ago  33 applicants         Associate
# 19               New York, NY    1 week ago           None  Mid-Senior level
# 20              United States     1 day ago           None         Associate
# 21                 Austin, TX    1 week ago           None  Mid-Senior level
# 22              United States   3 weeks ago           None  Mid-Senior level
# 23              United States    6 days ago           None       Entry level
# 24              United States    6 days ago           None  Mid-Senior level
# 25               New York, NY    6 days ago           None  Mid-Senior level
# 26              United States    1 week ago           None  Mid-Senior level
# 27          San Francisco, CA  2 months ago           None  Mid-Senior level
#
#      job_type                                        job_sectors  \
# 0   Full-time                               Software Development
# 1   Full-time                      IT Services and IT Consulting
# 2   Full-time                                         Automotive
# 3   Full-time                                 Financial Services
# 4   Full-time                                 Financial Services
# 5   Full-time                                Internet Publishing
# 6   Full-time                                    Design Services
# 7   Full-time                              Investment Management
# 8   Full-time                            Entertainment Providers
# 9   Full-time                               Software Development
# 10  Full-time                  Technology, Information and Media
# 11  Full-time                      IT Services and IT Consulting
# 12  Full-time                               Software Development
# 13  Full-time                            Entertainment Providers
# 14  Full-time  Software Development, Technology, Information ...
# 15  Full-time                            Entertainment Providers
# 16  Full-time                       Online Audio and Video Media
# 17  Full-time                                            Banking
# 18  Full-time  Hospitality, Food and Beverage Services, and R...
# 19  Full-time  Food and Beverage Services, Information Servic...
# 20  Full-time  Hospitality, Food and Beverage Services, and R...
# 21  Full-time                               Software Development
# 22  Full-time                     Internet Marketplace Platforms
# 23  Full-time                               Software Development
# 24  Full-time                                    Design Services
# 25  Full-time                                    Design Services
# 26  Full-time               Technology, Information and Internet
# 27  Full-time                                Internet Publishing
#
#                                       job_description
# 0   As part of the Data Engineering team, you will...
# 1   Middle Seat is a full-service media and fundra...
# 2   The Data team leverages data from our autonomo...
# 3   About Us\nMove money. Make money. Finix is a f...
# 4   Are you passionate about turning raw data into...
# 5   Job Title: Data Engineer/Senior Data Engineer/...
# 6   Figma is growing our team of passionate creati...
# 7   Americas\nAsset Management\nNew York\nLazard i...
# 8   Netflix is one of the world's leading entertai...
# 9   Who We Are\nSamsara (NYSE: IOT) is the pioneer...
# 10  Ibotta is looking for a software-focused\nData...
# 11  Job Title:\nJunior Data Engineer (Campus Hire)...
# 12  In the next 30 years, the world will transform...
# 13  Netflix is one of the world's leading entertai...
# 14  The main goal of the DE team in 2024-25 is to ...
# 15  Netflix is one of the world's leading entertai...
# 16  Bustle Digital Group (BDG) is looking for a ta...
# 17  Description\nLeader Bank is looking for except...
# 18  Employment Type: Full-Time, Mid-level\nDepartm...
# 19  About the Role\nWe are a fast-growing, consume...
# 20  Employment Type: Full-Time, Mid-level\nDepartm...
# 21  Job Description\nWhat if you could use your te...
# 22  Courtyard.io is the fastest-growing collectibl...
# 23  Overview\nMojoTech, established in 2008, is an...
# 24  Figma is growing our team of passionate creati...
# 25  Figma is growing our team of passionate creati...
# 26  Job Description\nAbout this role\nAs a Data En...
# 27  Protecht is reinventing refunds, striving to m...

# %%
import re
key_tools = [

    # 🧑‍💻 Programming Languages
    'Python', 'R', 'Java', 'Scala', 'SQL', 'NoSQL', 'Julia', 'TypeScript', 'JavaScript', 'Go', 'C++',

    # 📊 Data Analysis & Manipulation
    'Pandas', 'NumPy', 'Dask', 'Polars', 'OpenRefine', 'Tidyverse', 'DataFrames', 'Vaex', 'Koalas', 'Pyspark'

    # 🤖 Machine Learning & AI
    'Scikit-learn', 'TensorFlow', 'PyTorch', 'Keras', 'XGBoost', 'LightGBM', 'CatBoost',
    'FastAI', 'MLlib', 'H2O.ai', 'AutoML', 'DeepLearning4j', 'Optuna', 'MLflow', 'Hugging Face', 'ONNX',

    # 📈 Data Visualization
    'Matplotlib', 'Seaborn', 'Plotly', 'Bokeh', 'Altair', 'Dash',
    'Tableau', 'Power BI', 'Looker', 'QuickSight', 'Google Data Studio', 'Superset', 'QlikView', 'MicroStrategy',

    # ☁️ Cloud Platforms
    'AWS', 'Amazon S3', 'Athena', 'Redshift', 'Glue', 'Lambda',
    'GCP', 'BigQuery', 'Dataflow', 'Google Cloud Storage', 'Vertex AI',
    'Azure', 'Azure Synapse', 'Azure Data Lake', 'Azure ML', 'Databricks', 'Data Factory', 'Blob Storage'

    # 🧱 Databases & Warehousing
    'PostgreSQL', 'MySQL', 'SQL Server', 'Oracle', 'SQLite',
    'Snowflake', 'Databricks', 'ClickHouse', 'Vertica', 'Greenplum',
    'MongoDB', 'Cassandra', 'Elasticsearch', 'InfluxDB', 'Redis', 'Neo4j', 'DynamoDB',

    # 🗃️ Data Pipelines & ETL/ELT
    'Apache Airflow', 'Luigi', 'DBT', 'Apache NiFi', 'Kafka', 'Apache Beam', 'Apache Flink',
    'Fivetran', 'Stitch', 'Matillion', 'Informatica', 'Talend', 'Singer', 'Pentaho', 'StreamSets',

    # 🧪 Experimentation & Statistics
    'A/B Testing', 'Bayesian', 'Frequentist', 'T-Tests', 'P-Values', 'Hypothesis Testing', 'Randomized Control Trials',
    'Statsmodels', 'Prophet', 'PyMC3', 'SciPy', 'RStan',

    # 🧠 NLP & Text Analytics
    'spaCy', 'NLTK', 'Gensim', 'BERT', 'T5', 'LLaMA', 'OpenAI', 'LangChain', 'TextBlob', 'transformers',

    # 📦 DevOps, CI/CD, and Containers
    'Docker', 'Kubernetes', 'Terraform', 'Git', 'GitHub Actions', 'Jenkins', 'CircleCI', 'Ansible', 'ArgoCD',

    # 🛠 MLOps & Workflow Orchestration
    'MLflow', 'Kubeflow', 'Tecton', 'ZenML', 'Dagster', 'SageMaker Pipelines', 'Metaflow', 'Weights & Biases',

    # 📡 APIs & Web Services
    'REST API', 'GraphQL', 'gRPC', 'OpenAPI', 'FastAPI', 'Flask', 'Django',

    # 🔐 Security, Monitoring & Governance
    'Apache Ranger', 'Great Expectations', 'Monte Carlo', 'DataDog', 'Alation', 'Collibra', 'DataHub', 'Bigeye',

    # 📁 File Formats & Serialization
    'Parquet', 'Avro', 'ORC', 'Feather', 'CSV', 'JSON', 'XML', 'YAML', 'HDF5', 'Pickle',

    # 🧠 Data Science Notebooks & IDEs
    'Jupyter', 'VS Code', 'JupyterLab', 'Colab', 'Zeppelin', 'RStudio', 'PyCharm',

    # 🏢 Business Tools
    'Excel', 'Google Sheets', 'Smartsheet', 'Airtable', 'SAP', 'Salesforce',

    # 🛡️ Operating Systems & Scripting
    'Linux', 'Shell', 'Bash', 'PowerShell', 'zsh',

    # 🔁 Scheduling & Workflow Tools
    'Apache Oozie', 'Prefect', 'Crontab', 'RunDeck', 'Control-M'
]



def extract_tools(text):
    if not isinstance(text, str):
        return []
    found = [tool for tool in key_tools if re.search(r'\b' + re.escape(tool) + r'\b', text, flags=re.IGNORECASE)]
    return found

jobs_df['extracted_tools'] = jobs_df['job_description'].apply(extract_tools)

import pandas as pd
from datetime import datetime, timedelta
import re


def parse_relative_date(text):
    if not isinstance(text, str):
        return pd.NaT
    text = text.lower()
    now = datetime.now()

    patterns = {
        'hour': r'(\d+)\s+hour',
        'day': r'(\d+)\s+day',
        'week': r'(\d+)\s+week',
        'month': r'(\d+)\s+month',
        'year': r'(\d+)\s+year',
        'minute': r'(\d+)\s+minute'
    }

    for unit, pattern in patterns.items():
        match = re.search(pattern, text)
        if match:
            value = int(match.group(1))
            if unit == 'hour':
                return (now - timedelta(hours=value)).date()
            elif unit == 'day':
                return (now - timedelta(days=value)).date()
            elif unit == 'week':
                return (now - timedelta(weeks=value)).date()
            elif unit == 'month':
                return (now - timedelta(days=30*value)).date() 
            elif unit == 'year':
                return (now - timedelta(days=365*value)).date() # Approximate
            elif unit == 'minute':
                return (now - timedelta(minutes=value)).date()

    return pd.NaT


jobs_df['time_posted'] = jobs_df['time_posted'].apply(parse_relative_date)
jobs_df['time_posted'] = pd.to_datetime(jobs_df['time_posted']).dt.date

# %%
jobs_df
# Out:
#         job_id                                          job_title  \
# 0   4252403261                               Senior Data Engineer
# 1   4232940657                                      Data Engineer
# 2   4124931707                                      Data Engineer
# 3   4160656913                                      Data Engineer
# 4   4227411210                               Junior Data Engineer
# 5   4257708833  Data Engineer/Senior Data Engineer/Lead Data E...
# 6   3970353535                                      Data Engineer
# 7   4246012425                                      Data Engineer
# 8   4179982116  Data Engineer (L5) - Content Production & Prom...
# 9   4212085122                               Senior Data Engineer
# 10  4216499552                                      Data Engineer
# 11  4251972021                               Junior Data Engineer
# 12  4235550250                                      Data Engineer
# 13  4209905359                         Data Engineer 5 - Playback
# 14  4230106830                   Data Engineer - Data Engineering
# 15  4208343571  Software Engineer (L4) - Member, Commerce & Ga...
# 16  4209157444                                      Data Engineer
# 17  4233100791                                      Data Engineer
# 18  4260001898                                  Sr. Data Engineer
# 19  4254134391                               Senior Data Engineer
# 20  4260004537                                  Sr. Data Engineer
# 21  4255376438                               Senior Data Engineer
# 22  4243686674                                      Data Engineer
# 23  4187566335                          Data & Analytics Engineer
# 24  3970356046                                      Data Engineer
# 25  3970352584                                      Data Engineer
# 26  4239626016                                  Data Engineer III
# 27  4218006269                                      Data Engineer
#
#                                  company_name work_model  \
# 0                                       Asana     Hybrid
# 1                                 Middle Seat     Remote
# 2                                        Zoox     Hybrid
# 3                                       Finix     Hybrid
# 4                           Rize Credit Union     Hybrid
# 5                            ClearNote Health     Remote
# 6                                       Figma     Remote
# 7                     Lazard Asset Management     Hybrid
# 8                                     Netflix     Remote
# 9                                     Samsara     Remote
# 10                                     Ibotta     Hybrid
# 11                        The Value Maximizer     Hybrid
# 12                                      Paces     Hybrid
# 13                                    Netflix     Remote
# 14                                      Plaid     Hybrid
# 15                                    Netflix     Remote
# 16                                        BDG     Hybrid
# 17                                Leader Bank     Remote
# 18  CGS Federal (Contact Government Services)     Remote
# 19                                    Andiamo     Remote
# 20  CGS Federal (Contact Government Services)     Remote
# 21                       Procore Technologies     Remote
# 22                               Courtyard.io     Remote
# 23                                   MojoTech     Remote
# 24                                      Figma     Remote
# 25                                      Figma     Remote
# 26                                   Fanatics     Remote
# 27                                   Protecht     Remote
#
#                      location time_posted num_applicants          xp_level  \
# 0           San Francisco, CA  2025-06-24           None         Associate
# 1              Washington, DC  2025-06-01           None       Entry level
# 2             Foster City, CA  2025-06-24           None    Not Applicable
# 3           San Francisco, CA  2025-06-29           None       Entry level
# 4               Irwindale, CA  2025-06-01           None  Mid-Senior level
# 5               San Diego, CA  2025-06-26           None  Mid-Senior level
# 6           San Francisco, CA  2025-06-24           None  Mid-Senior level
# 7     New York, United States  2025-06-17           None       Entry level
# 8               United States  2025-06-29           None    Not Applicable
# 9               United States  2025-06-28           None  Mid-Senior level
# 10                 Denver, CO  2025-06-17           None       Entry level
# 11  New Jersey, United States  2025-06-24  30 applicants  Mid-Senior level
# 12               Brooklyn, NY  2025-06-01           None       Entry level
# 13              United States  2025-06-24           None    Not Applicable
# 14          San Francisco, CA  2025-06-26           None  Mid-Senior level
# 15              United States  2025-06-26           None    Not Applicable
# 16               New York, NY  2025-06-01           None       Entry level
# 17              United States  2025-07-01           None       Entry level
# 18              United States  2025-06-30  33 applicants         Associate
# 19               New York, NY  2025-06-24           None  Mid-Senior level
# 20              United States  2025-06-30           None         Associate
# 21                 Austin, TX  2025-06-24           None  Mid-Senior level
# 22              United States  2025-06-10           None  Mid-Senior level
# 23              United States  2025-06-25           None       Entry level
# 24              United States  2025-06-25           None  Mid-Senior level
# 25               New York, NY  2025-06-25           None  Mid-Senior level
# 26              United States  2025-06-24           None  Mid-Senior level
# 27          San Francisco, CA  2025-05-02           None  Mid-Senior level
#
#      job_type                                        job_sectors  \
# 0   Full-time                               Software Development
# 1   Full-time                      IT Services and IT Consulting
# 2   Full-time                                         Automotive
# 3   Full-time                                 Financial Services
# 4   Full-time                                 Financial Services
# 5   Full-time                                Internet Publishing
# 6   Full-time                                    Design Services
# 7   Full-time                              Investment Management
# 8   Full-time                            Entertainment Providers
# 9   Full-time                               Software Development
# 10  Full-time                  Technology, Information and Media
# 11  Full-time                      IT Services and IT Consulting
# 12  Full-time                               Software Development
# 13  Full-time                            Entertainment Providers
# 14  Full-time  Software Development, Technology, Information ...
# 15  Full-time                            Entertainment Providers
# 16  Full-time                       Online Audio and Video Media
# 17  Full-time                                            Banking
# 18  Full-time  Hospitality, Food and Beverage Services, and R...
# 19  Full-time  Food and Beverage Services, Information Servic...
# 20  Full-time  Hospitality, Food and Beverage Services, and R...
# 21  Full-time                               Software Development
# 22  Full-time                     Internet Marketplace Platforms
# 23  Full-time                               Software Development
# 24  Full-time                                    Design Services
# 25  Full-time                                    Design Services
# 26  Full-time               Technology, Information and Internet
# 27  Full-time                                Internet Publishing
#
#                                       job_description  \
# 0   As part of the Data Engineering team, you will...
# 1   Middle Seat is a full-service media and fundra...
# 2   The Data team leverages data from our autonomo...
# 3   About Us\nMove money. Make money. Finix is a f...
# 4   Are you passionate about turning raw data into...
# 5   Job Title: Data Engineer/Senior Data Engineer/...
# 6   Figma is growing our team of passionate creati...
# 7   Americas\nAsset Management\nNew York\nLazard i...
# 8   Netflix is one of the world's leading entertai...
# 9   Who We Are\nSamsara (NYSE: IOT) is the pioneer...
# 10  Ibotta is looking for a software-focused\nData...
# 11  Job Title:\nJunior Data Engineer (Campus Hire)...
# 12  In the next 30 years, the world will transform...
# 13  Netflix is one of the world's leading entertai...
# 14  The main goal of the DE team in 2024-25 is to ...
# 15  Netflix is one of the world's leading entertai...
# 16  Bustle Digital Group (BDG) is looking for a ta...
# 17  Description\nLeader Bank is looking for except...
# 18  Employment Type: Full-Time, Mid-level\nDepartm...
# 19  About the Role\nWe are a fast-growing, consume...
# 20  Employment Type: Full-Time, Mid-level\nDepartm...
# 21  Job Description\nWhat if you could use your te...
# 22  Courtyard.io is the fastest-growing collectibl...
# 23  Overview\nMojoTech, established in 2008, is an...
# 24  Figma is growing our team of passionate creati...
# 25  Figma is growing our team of passionate creati...
# 26  Job Description\nAbout this role\nAs a Data En...
# 27  Protecht is reinventing refunds, striving to m...
#
#                                       extracted_tools
# 0   [Python, Java, Scala, SQL, AWS, Redshift, Data...
# 1   [Python, SQL, Looker, AWS, Redshift, DBT, Exce...
# 2                         [Python, Scala, SQL, Kafka]
# 3   [Python, Java, SQL, Go, Tableau, Looker, Super...
# 4   [Python, R, SQL, Power BI, QuickSight, AWS, GC...
# 5                                    [Python, R, SQL]
# 6   [Python, SQL, Go, Snowflake, DBT, Dagster, Sal...
# 7   [Python, SQL, Azure, Git, Ansible, YAML, Linux...
# 8                                      [Python, Java]
# 9   [Python, SQL, AWS, Lambda, GCP, Azure, Databri...
# 10  [Python, Scala, SQL, AWS, Databricks, Databric...
# 11  [Python, SQL, AWS, GCP, Azure, MySQL, Oracle, ...
# 12  [Python, Scala, SQL, AWS, GCP, Azure, Dagster,...
# 13                         [Python, Java, Scala, SQL]
# 14  [Python, SQL, Redshift, Databricks, Snowflake,...
# 15                                                 []
# 16  [Python, SQL, TypeScript, AWS, Redshift, GCP, ...
# 17                [Python, SQL, Snowflake, Matillion]
# 18       [Python, R, SQL, Tableau, Git, Linux, Shell]
# 19  [Python, SQL, AWS, Redshift, BigQuery, Databri...
# 20       [Python, R, SQL, Tableau, Git, Linux, Shell]
# 21  [Python, SQL, Tableau, AWS, Databricks, Snowfl...
# 22  [Python, SQL, GCP, BigQuery, DBT, Docker, Kube...
# 23  [Python, TensorFlow, PyTorch, Tableau, Power B...
# 24  [Python, SQL, Go, Snowflake, DBT, Dagster, Sal...
# 25  [Python, SQL, Go, Snowflake, DBT, Dagster, Sal...
# 26  [Python, R, SQL, NoSQL, Tableau, MicroStrategy...
# 27  [Python, Java, SQL, Tableau, Looker, AWS, Athe...

# %%
db_params = {

}



try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(**db_params)
    cursor = conn.cursor()
    
    # SQL Insert Query
    insert_query = """
    INSERT INTO linkedin_jobs (
        job_id, job_title, company_name, work_model, location,
        time_posted, num_applicants, xp_level, job_type,
        job_sectors, job_description, extracted_tools
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (job_id) DO NOTHING;  -- Avoids duplicate primary key errors
"""

    
    # Insert DataFrame records one by one
    for _, row in jobs_df.iterrows():
        cursor.execute(insert_query, (
            row['job_id'],
            row['job_title'],
            row['company_name'],
            row['work_model'],
            row['location'],
            row['time_posted'],  # Make sure this is a `date` object
            row['num_applicants'],
            row['xp_level'],
            row['job_type'],
            row['job_sectors'],
            row['job_description'],
            row['extracted_tools']  # Should be a Python list, e.g., ['Python', 'SQL']
    ))

    # Commit and close
    conn.commit()
    print("Data inserted successfully!")

except Exception as e:
    print(e)

finally:
    if conn:
        cursor.close()
        conn.close
# Out:
# Data inserted successfully!
